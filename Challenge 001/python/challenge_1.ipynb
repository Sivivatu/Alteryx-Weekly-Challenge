# %%
# Drive operations
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Data manipulation
import pandas as pd

# %%
# authenticate to Google Drive
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %% [markdown]
# Import the two files required for the analysis. the left input is the customer list and their areas. the Right input lists the sales reps and the postal areas they cover.

# %%
# Download files
left_input_id = '1WIQqrBdDbPWhBpNQFr0LhBz8WZf87Nm8'
right_input_id = '1WGy4-harNZxr47tmMHKHYA0qpE9cTykz'


left_input_downloaded = drive.CreateFile({'id': left_input_id})
left_input_downloaded.GetContentFile('left_input.csv')
right_input_downloaded = drive.CreateFile({'id': right_input_id})
right_input_downloaded.GetContentFile('right_input.csv')

df_left = pd.read_csv('left_input.csv')
df_right = pd.read_csv('right_input.csv')

print(df_left.head())
print(df_right.head())
# Out:
#    Customer ID  Store Number Customer Segment Responder  Postal Area
# 0            2           100        Corporate        No         2086
# 1            3           100        Corporate        No         2051
# 2            5           100      Home Office        No         2077
# 3            6           106      Home Office        No         2004
# 4            8           101      Home Office        No         2010
#        Range Region Sales Rep  Expect Revenue
# 0  2000-2019     R1      John         1000000
# 1  2020-2039     R2       Ted         3245234
# 2  2040-2059     R3      Nick          456654
# 3  2060-2079     R4      Mike          234545
# 4  2080-2100     R5      Paul         1232345

# %% [markdown]
# Process the intitial Right input (the sales reps) to identify the range of postal areas they cover

# %%
df_range = df_right['Range'].str.split('-', expand=True)
df_range.columns = ['start', 'end']
print(df_range)
df_right = pd.concat([df_right, df_range], axis=1)
print(df_right.head())
# Out:
#   start   end
# 0  2000  2019
# 1  2020  2039
# 2  2040  2059
# 3  2060  2079
# 4  2080  2100
#        Range Region Sales Rep  Expect Revenue start   end
# 0  2000-2019     R1      John         1000000  2000  2019
# 1  2020-2039     R2       Ted         3245234  2020  2039
# 2  2040-2059     R3      Nick          456654  2040  2059
# 3  2060-2079     R4      Mike          234545  2060  2079
# 4  2080-2100     R5      Paul         1232345  2080  2100

# %% [markdown]
# create a new key field generating the records to match between start & end postcodes.

# %%
for i in df_right['Range']:
  range(df_right['Start'], df_right['End'])
  
  
print(range(df_right['Start'], df_right['End']))
# Out:
# KeyErrorTraceback (most recent call last)
# <ipython-input-10-f90c8f50d04c> in <module>()
# ----> 1 print(range(df_right['Start'], df_right['End']))
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
# ...
